# %%
# Install YOLOv8 and dependencies
# !pip install ultralytics
# !pip install roboflow opencv-python numpy torch torchvision
# Out:
# ...
# ERROR: Operation cancelled by user
# ...

# %%
#Imports
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0bf2fd45f7d1> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Mount Google drive for directory
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Safety_Vest_Detection.v1i.yolov8'

# Train YOLOv8n model
model = YOLO("yolov8n.pt")  # Using YOLOv8 nano for faster training
model.train(data=f"{path}/data.yaml", epochs=25, imgsz=640, batch=16, visualize=True) #try 25 epochs to start, visualize to understand parameters and layers
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model.save('/content/drive/MyDrive/yolov8_trained_model_25epoch.pt') #Save model for use on Jetson Nano
metrics = model.val(data=f"{path}/data.yaml", split="val") #Meassure performance on validation set
# Out:
# Ultralytics 8.3.91 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# val: Scanning /content/drive/.shortcut-targets-by-id/1PgnIiuwypgv0uJBQe_4fGecSeh1Pl3xB/Safety_Vest_Detection.v1i.yolov8/valid/labels.cache... 119 images, 40 backgrounds, 0 corrupt: 100%|██████████| 119/119 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:32<00:00,  4.12s/it]
#                    all        119        102       0.98      0.989      0.985      0.898
#               Hard Hat         45         45      0.995      0.978      0.981      0.897
#            Safety Vest         57         57      0.964          1      0.989        0.9
# Speed: 2.1ms preprocess, 255.6ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/train63

# %%
import cv2
import matplotlib.pyplot as plt

#Show confusion matrix of validation set
image_path = "/content/runs/detect/train63/confusion_matrix.png"  # Change path if needed
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import os
import random

#set function to see validation batches
def display_validation_batches(folder_path="/content/runs/detect/train"):
    """
    Function to load and display random validation batch images from a trained YOLOv8 model.

    :param folder_path: Path to the training results folder where batch images are stored.
    """
    # Ensure the folder exists
    if not os.path.exists(folder_path):
        print("Error: Folder does not exist!")
        return

    # Get all batch images from training logs
    batch_images = [f for f in os.listdir(folder_path) if f.startswith("val_batch") and f.endswith(".jpg")]

    if not batch_images:
        print("No validation batch images found. Make sure you ran model.val() first!")
        return

    # Randomly pick up to 6 images for display
    num_images = min(6, len(batch_images))  # Display up to 6 images
    selected_images = random.sample(batch_images, num_images)

    # Plot the selected images in a grid
    fig, axes = plt.subplots(1, num_images, figsize=(20, 10))

    if num_images == 1:
        axes = [axes]  # Ensure axes is iterable for a single image case

    for i, img_name in enumerate(selected_images):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert color for Matplotlib

        axes[i].imshow(img)
        axes[i].axis("off")
        axes[i].set_title(f"Batch: {img_name}")

    plt.show()

# Run the function
display_validation_batches("/content/runs/detect/train63")

# %%
import cv2
import matplotlib.pyplot as plt
import os
import random


#Used for further testing to figure out why detections were not occuring on low epoch training.
#Redundant function when compared to previous cell
def display_ground_truth_vs_predictions(folder_path="/content/runs/detect/train/"):
    """
    Displays validation batch images comparing ground truth vs predictions.

    :param folder_path: Path to the training results folder where batch images are stored.
    """
    # Ensure the folder exists
    if not os.path.exists(folder_path):
        print("Error: Folder does not exist!")
        return

    # Get all batch images for ground truth and predictions
    gt_images = [f for f in os.listdir(folder_path) if f.startswith("val_batch") and f.endswith("labels.jpg")]
    pred_images = [f.replace("labels", "pred") for f in gt_images]  # Get corresponding predictions

    if not gt_images or not pred_images:
        print("No validation batch images found. Make sure you ran model.val() first!")
        return

    # Randomly pick up to 3 images for display
    num_images = min(3, len(gt_images))  # Display up to 3 images
    selected_gt_images = random.sample(gt_images, num_images)

    # Create a 2-row grid: (Top row = ground truth, Bottom row = predictions)
    fig, axes = plt.subplots(2, num_images, figsize=(20, 10))

    if num_images == 1:
        axes = [axes]  # Ensure axes is iterable for a single image case

    for i, gt_img_name in enumerate(selected_gt_images):
        gt_img_path = os.path.join(folder_path, gt_img_name)
        # Moved the pred_img_name assignment inside the loop
        pred_img_name = gt_img_name.replace("labels", "pred")
        pred_img_path = os.path.join(folder_path, pred_img_name)

        gt_img = cv2.imread(gt_img_path)
        gt_img = cv2.cvtColor(gt_img, cv2.COLOR_BGR2RGB)

        pred_img = cv2.imread(pred_img_path)
        pred_img = cv2.cvtColor(pred_img, cv2.COLOR_BGR2RGB)

        # Top row: Ground Truth
        axes[0, i].imshow(gt_img)
        axes[0, i].axis("off")
        axes[0, i].set_title(f"Ground Truth: {gt_img_name}")

        # Bottom row: Predictions
        axes[1, i].imshow(pred_img)
        axes[1, i].axis("off")
        axes[1, i].set_title(f"Predictions: {pred_img_name}")

    plt.show()

# Run the function
display_ground_truth_vs_predictions("/content/runs/detect/train63")

# %%
#Test the model and speed on a sample photo
import cv2
from ultralytics import YOLO
# Import the necessary patch for displaying images in Colab
from google.colab.patches import cv2_imshow

# Load YOLOv8 model
model = YOLO("/content/drive/MyDrive/yolov8_trained_model_25epoch.pt")

# Run inference
results = model("/content/drive/MyDrive/Test_Pic.jpg", conf=0.2, iou=0.3)

# Get the image with bounding boxes drawn
for result in results:
    annotated_frame = result.plot()  # Automatically plots bounding boxes on the image

# Display the image using cv2_imshow() instead of cv2.imshow()
cv2_imshow(annotated_frame)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#test on a sample video uploaded to directory
import cv2
import torch
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from IPython.display import clear_output

# Load YOLO model
model = YOLO('/content/drive/MyDrive/yolov8_trained_model_25epoch.pt')

# Open video
# video_path = "/content/drive/MyDrive/Video_Test_2.mp4"
video_path = 0 # Change to 0 for webcam
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get video properties
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define video writer to save output as MP4
output_path = "Video_Test.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # MP4 codec
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define fixed colors for bounding boxes (Red, Green, Blue)
fixed_colors = [(0, 0, 255), (255, 0, 0), (0, 255, 0)]  # Red, Green, Blue

# Loop through video frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Exit loop if video ends

    # Run YOLOv8 inference on the frame
    results = model(frame, conf=0.2, iou=0.3)

    # Draw bounding boxes
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
            conf = box.conf[0].item()  # Confidence score
            cls = int(box.cls[0].item())  # Class ID
            label = f"{model.names[cls]}: {conf:.2f}"  # Class label

            # Cycle through Red, Green, and Blue
            color = fixed_colors[cls % 3]

            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Write frame to output video
    out.write(frame)

    # Display frame in Colab
    cv2_imshow(frame)
    clear_output(wait=True)  # Clear the output to display the next frame

# Release resources
cap.release()
out.release()

print(f"Processed video saved as {output_path}")
# Out:
# Processed video saved as Video_Test.mp4

# %%
from ultralytics import YOLO

# Load YOLO model
model = YOLO('/content/drive/MyDrive/yolov8_trained_model_25epoch.pt')
model.export(format="onnx", opset=12) #output as onnx for use on jetson nano - NOTE: ONNX was not functioning properly so we used .pt file for our live demo
# Out:
# Ultralytics 8.3.92 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from '/content/drive/MyDrive/yolov8_trained_model_25epoch.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.9 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 119.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 135.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 104.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 80.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 134.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 12.4s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ...
